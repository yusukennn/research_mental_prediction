# %%
import pandas as pd
import datetime as dt
import seaborn as sns
import numpy as np

# %%
ques_act_ampm = pd.read_csv('../../datas/ques_act_merge/ques_act_ampm.csv')
ques_act_day = pd.read_csv('../../datas/ques_act_merge/ques_act_day.csv')
att_weather = pd.read_csv('../../datas/attribute_weater.csv')

# %%
ques_act_day.columns
# Out:
# Index(['Unnamed: 0', 'user_id', 'value_dams', 'datetime_jp', 'Date_jp',
#        'hour_x', 'positive_score', 'depressive_score', 'anxious_score',
#        'datetime_jp_before3', 'datetime_jp_before6', 'datetime_jp_before9',
#        'datetime_jp_before12', 'datetime_jp_before24', 'meeting_ftof', 'Date',
#        'activity_type_id', 'hour_y', 'am_pm', 'meal', 'working_alone',
#        'hobby_break', 'housework_childcare', 'break', 'transfer',
#        'web_conference', 'other', 'work_outsideduty', 'facetoface_meeting',
#        'collaboration', 'remote_conference', 'Days_plus1'],
#       dtype='object')

# %%
ques_act_day_corr = ques_act_day[['positive_score', 'depressive_score', 'anxious_score',
       'meeting_ftof', 'meal', 'working_alone',
       'hobby_break', 'housework_childcare', 'break', 'transfer',
       'web_conference', 'other', 'work_outsideduty', 'facetoface_meeting',
       'collaboration', 'remote_conference']]

# %%
ques_act_day_corr
# Out:
#       positive_score  depressive_score  anxious_score meeting_ftof       meal  \
# 0           5.666667          0.666667            1.0            0   0.044983
# 1           3.666667          3.000000            2.0            0   6.866667
# 2           2.333333          0.000000            1.0            0   0.010333
# 3           0.333333          0.000000            4.0            0   7.967950
# 4           4.000000          3.000000            3.0            0  57.242667
# ...              ...               ...            ...          ...        ...
# 1134        6.666667          2.000000            3.0            0   0.000000
# 1135        6.666667          2.000000            3.0            0  22.000000
# 1136        3.000000          0.333333            2.0            0  25.000000
# 1137        5.000000          0.000000            0.0            0  30.000000
# 1138        6.000000          0.000000            0.0            0  63.356767
#
#       working_alone  hobby_break  housework_childcare  break    transfer  \
# 0          0.000000     0.000000                 0.00    0.0   30.000000
# 1          0.000000    45.633333                 3.25    0.0    0.000000
# 2          0.000000     0.000000                 0.00    0.0    0.000000
# 3          0.000000     0.000000                 0.00    0.0   86.880667
# 4          0.000000     0.000000                 0.00    0.0    0.000000
# ...             ...          ...                  ...    ...         ...
# 1134     163.749867     0.000000                 0.00   30.0  135.000000
# 1135     531.000000     0.000000                80.00   50.0    0.000000
# 1136     261.000000   187.987483                 0.00   45.4  182.853700
# 1137     400.063700     0.000000                 0.00    0.0    0.000000
# 1138     322.150000   223.162050                59.60   28.8  143.300000
#
#       web_conference      other  work_outsideduty  facetoface_meeting  \
# 0                0.0  71.223333          0.000000                 0.0
# 1                0.0   0.000000          0.017717                 0.0
# 2                0.0   0.000000          0.000000                 0.0
# 3                0.0  47.286383          0.000000                 0.0
# 4                0.0   0.000000          0.000000                 0.0
# ...              ...        ...               ...                 ...
# 1134             0.0   0.000000          0.000000                 0.0
# 1135             0.0   0.000000          0.000000                 0.0
# 1136           211.2   0.000000          0.000000                 0.0
# 1137            60.0   0.000000          0.000000                 0.0
# 1138             0.0   0.000000          0.000000                 0.0
#
#       collaboration  remote_conference
# 0          0.000000                0.0
# 1          0.000000                0.0
# 2          0.000000                0.0
# 3          0.000000                0.0
# 4          0.000000                0.0
# ...             ...                ...
# 1134      40.026833                0.0
# 1135       0.000000               10.0
# 1136       0.000000                0.0
# 1137       0.000000                0.0
# 1138       0.000000                0.0
#
# [1139 rows x 16 columns]

# %%
corr = ques_act_day_corr.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
att_weather = att_weather[['user_id', 'sex', 'age', 'locate_id',
       'locate_name', 'Date', 'ave_temperature', 'max_temperature',
       'mini_temperature', 'sum_rainfall', 'sunlight_time', 'ave_windspeed',
       'max_windspeed', 'ave_vaporpressure', 'ave_cloudcover', 'weather_6to18',
       'weather_18to6', 'locate']]

# %%
att_weather['weather_6to18'].unique()
# Out:
# array(['曇', 'みぞれ時々曇一時晴後雨', '晴', '曇一時晴', '曇時々晴', '晴後一時曇', '雨一時曇', '雨後時々曇',
#        '晴時々曇', '雨時々曇', '曇一時晴後雨、みぞれを伴う', '曇後時々晴', 'みぞれ時々雨後曇', '晴一時曇',
#        '曇後雨時々晴', 'みぞれ時々晴一時雪後曇', '雨', '曇時々晴一時雨', '雨時々曇、みぞれを伴う',
#        '曇一時雨後晴、みぞれを伴う', '雨時々曇後晴', '曇後時々晴一時雨', '雪時々曇後晴', '晴後曇一時雨', '曇後時々雨',
#        '雪時々曇、みぞれを伴う', '曇後晴一時雪、みぞれを伴う', '晴一時雪、みぞれを伴う', '薄曇', '快晴',
#        '曇後晴一時雨', '曇後一時晴', '晴後一時薄曇', '薄曇一時晴', '晴後雪', '雨後曇', '晴一時薄曇',
#        '曇時々雨', '雨後一時曇', '曇後晴', '曇一時雪', '曇一時雪後一時晴', '雪時々みぞれ後曇一時晴',
#        '曇一時雪後晴', '晴後曇一時雨、みぞれを伴う', '晴時々曇、みぞれを伴う', '曇時々晴後雨', '晴時々曇一時雪',
#        '晴後時々曇', 'みぞれ時々雪後曇一時雨', '雪時々晴後曇、みぞれを伴う', '曇時々雨一時晴',
#        '晴一時雪後曇、みぞれを伴う', '晴時々雨一時曇', '雪後みぞれ時々曇一時雨', '雨時々曇一時晴、雷を伴う',
#        '曇一時雪後晴、みぞれを伴う', '曇一時雨後時々晴', '晴後曇一時雪', '雨時々みぞれ一時曇', '雪時々曇',
#        '曇時々雪一時晴', '曇後時々雨、みぞれを伴う', '雨時々晴後曇', '曇時々晴後雪、みぞれを伴う', '雪', '雪後一時曇',
#        '晴時々曇一時雨', '雨後晴', '曇一時雨', '雪後晴', '雪時々曇一時晴', '雪一時晴', '曇後雨一時みぞれ',
#        '曇時々雪一時みぞれ', '晴後時々薄曇', '薄曇後一時雨', '薄曇時々晴', '曇一時雪、みぞれを伴う', '曇一時雨後晴',
#        '曇時々雪一時晴、みぞれを伴う', '曇一時雪後雨、雷を伴う', '晴時々雨一時曇、みぞれを伴う', '雪後曇一時晴',
#        '雨時々曇一時雪', '雪時々みぞれ一時曇', '晴時々雨後曇', '曇後一時雨', '曇後晴一時雪', '雪一時みぞれ後曇時々晴',
#        '曇後みぞれ一時雪', '晴後時々雨一時曇', '曇後みぞれ時々雨'], dtype=object)

# %%
att_weather.loc[att_weather['weather_6to18'].str.contains('晴',na=False),'weather_6to18']=2
att_weather.loc[att_weather['weather_6to18'].str.contains('雪',na=False),'weather_6to18']=0
att_weather.loc[att_weather['weather_6to18'].str.contains('雨',na=False),'weather_6to18']=0
att_weather.loc[att_weather['weather_6to18'].str.contains('曇',na=False),'weather_6to18']=1

att_weather.loc[att_weather['weather_18to6'].str.contains('晴',na=False),'weather_18to6']=2
att_weather.loc[att_weather['weather_18to6'].str.contains('雪',na=False),'weather_18to6']=0
att_weather.loc[att_weather['weather_18to6'].str.contains('雨',na=False),'weather_18to6']=0
att_weather.loc[att_weather['weather_18to6'].str.contains('曇',na=False),'weather_18to6']=1

# %%
dams_score = ques_act_day[['user_id','Date_jp','positive_score','depressive_score','anxious_score']]
att_weather['Date'] = pd.to_datetime(att_weather['Date'])
dams_score['Date_jp'] = pd.to_datetime(dams_score['Date_jp'])
dams_att_weather = pd.merge(dams_score,att_weather,left_on=['user_id','Date_jp'],right_on=['user_id','Date'],how='inner')
# Out:
# <ipython-input-10-754002e7b86a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dams_score['Date_jp'] = pd.to_datetime(dams_score['Date_jp'])

# %%
dams_att_weather.columns
# Out:
# Index(['user_id', 'Date_jp', 'positive_score', 'depressive_score',
#        'anxious_score', 'sex', 'age', 'locate_id', 'locate_name', 'Date',
#        'ave_temperature', 'max_temperature', 'mini_temperature',
#        'sum_rainfall', 'sunlight_time', 'ave_windspeed', 'max_windspeed',
#        'ave_vaporpressure', 'ave_cloudcover', 'weather_6to18', 'weather_18to6',
#        'locate'],
#       dtype='object')

# %%
dams_att_weather_corr = dams_att_weather[['positive_score', 'depressive_score',
       'anxious_score', 'sex', 'age', 
       'ave_temperature', 'max_temperature', 'mini_temperature',
       'sum_rainfall', 'sunlight_time', 'ave_windspeed', 'max_windspeed',
       'ave_vaporpressure', 'weather_6to18', 'weather_18to6']]

# %%
corr = dams_att_weather_corr.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
ques_act_day_corr
# Out:
#       positive_score  depressive_score  anxious_score meeting_ftof       meal  \
# 0           5.666667          0.666667            1.0            0   0.044983
# 1           3.666667          3.000000            2.0            0   6.866667
# 2           2.333333          0.000000            1.0            0   0.010333
# 3           0.333333          0.000000            4.0            0   7.967950
# 4           4.000000          3.000000            3.0            0  57.242667
# ...              ...               ...            ...          ...        ...
# 1134        6.666667          2.000000            3.0            0   0.000000
# 1135        6.666667          2.000000            3.0            0  22.000000
# 1136        3.000000          0.333333            2.0            0  25.000000
# 1137        5.000000          0.000000            0.0            0  30.000000
# 1138        6.000000          0.000000            0.0            0  63.356767
#
#       working_alone  hobby_break  housework_childcare  break    transfer  \
# 0          0.000000     0.000000                 0.00    0.0   30.000000
# 1          0.000000    45.633333                 3.25    0.0    0.000000
# 2          0.000000     0.000000                 0.00    0.0    0.000000
# 3          0.000000     0.000000                 0.00    0.0   86.880667
# 4          0.000000     0.000000                 0.00    0.0    0.000000
# ...             ...          ...                  ...    ...         ...
# 1134     163.749867     0.000000                 0.00   30.0  135.000000
# 1135     531.000000     0.000000                80.00   50.0    0.000000
# 1136     261.000000   187.987483                 0.00   45.4  182.853700
# 1137     400.063700     0.000000                 0.00    0.0    0.000000
# 1138     322.150000   223.162050                59.60   28.8  143.300000
#
#       web_conference      other  work_outsideduty  facetoface_meeting  \
# 0                0.0  71.223333          0.000000                 0.0
# 1                0.0   0.000000          0.017717                 0.0
# 2                0.0   0.000000          0.000000                 0.0
# 3                0.0  47.286383          0.000000                 0.0
# 4                0.0   0.000000          0.000000                 0.0
# ...              ...        ...               ...                 ...
# 1134             0.0   0.000000          0.000000                 0.0
# 1135             0.0   0.000000          0.000000                 0.0
# 1136           211.2   0.000000          0.000000                 0.0
# 1137            60.0   0.000000          0.000000                 0.0
# 1138             0.0   0.000000          0.000000                 0.0
#
#       collaboration  remote_conference
# 0          0.000000                0.0
# 1          0.000000                0.0
# 2          0.000000                0.0
# 3          0.000000                0.0
# 4          0.000000                0.0
# ...             ...                ...
# 1134      40.026833                0.0
# 1135       0.000000               10.0
# 1136       0.000000                0.0
# 1137       0.000000                0.0
# 1138       0.000000                0.0
#
# [1139 rows x 16 columns]

# %%
ques_act_day_corr['positive_score'].hist(bins=100).set(xlabel="Score", ylabel="Number of data")
# Out:
# [Text(0.5, 0, 'Score'), Text(0, 0.5, 'Number of data')]

# %%
ques_act_day_corr['anxious_score'].quantile([0, 0.3, 0.5, 0.7, 1.0])
# Out:
# 0.0     0.000000
# 0.3     0.666667
# 0.5     2.000000
# 0.7     3.333333
# 1.0    17.333333
# Name: anxious_score, dtype: float64

# %%
ques_act_day_corr.loc[ques_act_day_corr['positive_score']<=2.666667,'positive_class']=0
ques_act_day_corr.loc[(ques_act_day_corr['positive_score']>2.666667)&(ques_act_day_corr['positive_score']<4.66667),'positive_class']=1
ques_act_day_corr.loc[ques_act_day_corr['positive_score']>=4.66667,'positive_class']=2
# Out:
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
ques_act_day_corr
# Out:
#       positive_score  depressive_score  anxious_score meeting_ftof       meal  \
# 0           5.666667          0.666667            1.0            0   0.044983
# 1           3.666667          3.000000            2.0            0   6.866667
# 2           2.333333          0.000000            1.0            0   0.010333
# 3           0.333333          0.000000            4.0            0   7.967950
# 4           4.000000          3.000000            3.0            0  57.242667
# ...              ...               ...            ...          ...        ...
# 1134        6.666667          2.000000            3.0            0   0.000000
# 1135        6.666667          2.000000            3.0            0  22.000000
# 1136        3.000000          0.333333            2.0            0  25.000000
# 1137        5.000000          0.000000            0.0            0  30.000000
# 1138        6.000000          0.000000            0.0            0  63.356767
#
#       working_alone  hobby_break  housework_childcare  break    transfer  \
# 0          0.000000     0.000000                 0.00    0.0   30.000000
# 1          0.000000    45.633333                 3.25    0.0    0.000000
# 2          0.000000     0.000000                 0.00    0.0    0.000000
# 3          0.000000     0.000000                 0.00    0.0   86.880667
# 4          0.000000     0.000000                 0.00    0.0    0.000000
# ...             ...          ...                  ...    ...         ...
# 1134     163.749867     0.000000                 0.00   30.0  135.000000
# 1135     531.000000     0.000000                80.00   50.0    0.000000
# 1136     261.000000   187.987483                 0.00   45.4  182.853700
# 1137     400.063700     0.000000                 0.00    0.0    0.000000
# 1138     322.150000   223.162050                59.60   28.8  143.300000
#
#       web_conference      other  work_outsideduty  facetoface_meeting  \
# 0                0.0  71.223333          0.000000                 0.0
# 1                0.0   0.000000          0.017717                 0.0
# 2                0.0   0.000000          0.000000                 0.0
# 3                0.0  47.286383          0.000000                 0.0
# 4                0.0   0.000000          0.000000                 0.0
# ...              ...        ...               ...                 ...
# 1134             0.0   0.000000          0.000000                 0.0
# 1135             0.0   0.000000          0.000000                 0.0
# 1136           211.2   0.000000          0.000000                 0.0
# 1137            60.0   0.000000          0.000000                 0.0
# 1138             0.0   0.000000          0.000000                 0.0
#
#       collaboration  remote_conference  positive_class
# 0          0.000000                0.0             2.0
# 1          0.000000                0.0             1.0
# 2          0.000000                0.0             0.0
# 3          0.000000                0.0             0.0
# 4          0.000000                0.0             1.0
# ...             ...                ...             ...
# 1134      40.026833                0.0             2.0
# 1135       0.000000               10.0             2.0
# 1136       0.000000                0.0             1.0
# 1137       0.000000                0.0             2.0
# 1138       0.000000                0.0             2.0
#
# [1139 rows x 17 columns]

# %%
merged_fitbit = pd.read_csv('../../datas/fitbit_preprocessed_data/agg_for_day/merged_fitbit.csv')
sleep = pd.read_csv('../../datas/fitbit_preprocessed_data/agg_for_day/sleep_day.csv')

# %%
dams_score = ques_act_day[['user_id', 'value_dams', 'datetime_jp', 'Date_jp',
        'positive_score', 'depressive_score', 'anxious_score', 'Days_plus1']]
dams_score.loc[dams_score['positive_score']<=2.666667,'positive_class']=0
dams_score.loc[(dams_score['positive_score']>2.666667)&(dams_score['positive_score']<4.66667),'positive_class']=1
dams_score.loc[dams_score['positive_score']>=4.66667,'positive_class']=2

dams_score.loc[dams_score['depressive_score']<=0.333333,'depressive_class']=0
dams_score.loc[(dams_score['depressive_score']>0.333333)&(dams_score['depressive_score']<2.666667),'depressive_class']=1
dams_score.loc[dams_score['depressive_score']>=2.666667,'depressive_class']=2

dams_score.loc[dams_score['anxious_score']<=0.666667,'anxious_class']=0
dams_score.loc[(dams_score['anxious_score']>0.666667)&(dams_score['anxious_score']<3.333333),'anxious_class']=1
dams_score.loc[dams_score['anxious_score']>=3.333333,'anxious_class']=2
# Out:
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
ques_fitbit = pd.merge(dams_score, merged_fitbit,left_on=['user_id','Date_jp'],right_on=['user_id','date_plus1'])
ques_fitbit = pd.merge(ques_fitbit, sleep,left_on=['user_id','Date_jp'],right_on=['user_id','date'])

# %%
merged_fitbit['Dayminus1'] = pd.to_datetime(merged_fitbit['date'])-dt.timedelta(days=1)

# %%
ques_fitbit.columns
ques_fitbit_corr = ques_fitbit[[ 'positive_score',
       'depressive_score', 'anxious_score', 
       'floor_mean', 'floor_median', 'floor_var', 'step_mean', 'step_median',
       'step_var', 'mets_mean', 'calory_mean', 'mets_median', 'calory_median',
       'mets_var', 'calory_var', 'heart_mean', 'heart_median', 'heart_var',
       'minutesFairlyActive_mean', 'minutesFairlyActive_median',
       'minutesFairlyActive_var', 'minutesLightlyActive_mean',
       'minutesLightlyActive_median', 'minutesLightlyActive_var',
       'minutesSedentary_mean', 'minutesSedentary_median',
       'minutesSedentary_var', 'minutesVeryActive_mean',
       'minutesVeryActive_median', 'minutesVeryActive_var','sleep_mean_y', 'sleep_median_y',
       'sleep_var_y']]

# %%
corr = ques_fitbit_corr.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=80,
    horizontalalignment='right'
);

# %%
import pandas as pd # 基本ライブラリ
import numpy as np # 基本ライブラリ
import matplotlib.pyplot as plt # グラフ描画用
import seaborn as sns; sns.set() # グラフ描画用
import warnings # 実行に関係ない警告を無視
import lightgbm as lgb #LightGBM
from sklearn import datasets
from sklearn.model_selection import train_test_split # データセット分割用
from sklearn.metrics import accuracy_score # モデル評価用(正答率)
from sklearn.metrics import log_loss # モデル評価用(logloss)     
from sklearn.metrics import roc_auc_score # モデル評価用(auc)
from sklearn.metrics import confusion_matrix

# %%
# 説明変数,目的変数
y = ques_fitbit['positive_class'].values# 説明変数(target以外の特徴量)
X = ques_fitbit[[
       'floor_mean', 'floor_median', 'floor_var', 'step_mean', 'step_median',
       'step_var', 'mets_mean', 'calory_mean', 'mets_median', 'calory_median',
       'mets_var', 'calory_var', 'heart_mean', 'heart_median', 'heart_var',
       'minutesFairlyActive_mean', 'minutesFairlyActive_median',
       'minutesFairlyActive_var', 'minutesLightlyActive_mean',
       'minutesLightlyActive_median', 'minutesLightlyActive_var',
       'minutesSedentary_mean', 'minutesSedentary_median',
       'minutesSedentary_var', 'minutesVeryActive_mean',
       'minutesVeryActive_median', 'minutesVeryActive_var','sleep_mean_y', 'sleep_median_y',
       'sleep_var_y']].values # 目的変数(target)

# トレーニングデータ,テストデータの分割
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.20, random_state=2)

# %%
# モデルの学習
model = lgb.LGBMClassifier() # モデルのインスタンスの作成
model.fit(X_train, y_train) # モデルの学習

# テストデータの予測クラス (予測クラス(0 or 1 or 2)を返す)
y_pred = model.predict(X_test)
# テストデータのクラス予測確率 (各クラスの予測確率 [クラス0の予測確率,クラス1の予測確率,クラス2の予測確率] を返す)
y_pred_prob = model.predict_proba(X_test)

# %%
# 真値と予測値の表示
df_pred = pd.DataFrame({'target':y_test,'target_pred':y_pred})
display(df_pred)

# 真値と予測確率の表示
df_pred_prob = pd.DataFrame({'y':y_test, 'target0_prob':y_pred_prob[:,0], 'target1_prob':y_pred_prob[:,1], 'target2_prob':y_pred_prob[:,2]})
display(df_pred_prob)
# Out:
#     target  target_pred
# 0      2.0          0.0
# 1      1.0          2.0
# 2      1.0          1.0
# 3      0.0          0.0
# 4      1.0          0.0
# ..     ...          ...
# 90     2.0          0.0
# 91     1.0          1.0
# 92     0.0          1.0
# 93     1.0          0.0
# 94     2.0          1.0
#
# [95 rows x 2 columns]
#       y  target0_prob  target1_prob  target2_prob
# 0   2.0      0.970073      0.015768      0.014159
# 1   1.0      0.290574      0.068076      0.641349
# 2   1.0      0.399821      0.521576      0.078603
# 3   0.0      0.817231      0.163812      0.018957
# 4   1.0      0.500440      0.425712      0.073848
# ..  ...           ...           ...           ...
# 90  2.0      0.584617      0.247155      0.168228
# 91  1.0      0.053922      0.563105      0.382973
# 92  0.0      0.105931      0.888281      0.005788
# 93  1.0      0.986934      0.002944      0.010122
# 94  2.0      0.029108      0.950387      0.020505
#
# [95 rows x 4 columns]

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues').set(xlabel="predict label", ylabel="true label")
# Out:
# <AxesSubplot:>

# %%
import pandas as pd # 基本ライブラリ
import numpy as np # 基本ライブラリ
import matplotlib.pyplot as plt # グラフ描画用
import seaborn as sns; sns.set() # グラフ描画用
import warnings # 実行に関係ない警告を無視
warnings.filterwarnings('ignore')
import lightgbm as lgb #LightGBM
from sklearn import datasets
from sklearn.model_selection import train_test_split # データセット分割用

# %%
import lightgbm as lgb

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

X, y = ques_fitbit[['user_id',
       'floor_mean',  'floor_var', 'step_mean', 
       'step_var', 'mets_mean', 'calory_mean', 'mets_median', 'calory_median',
       'mets_var', 'calory_var', 'heart_mean', 'heart_median', 'heart_var',
       'minutesFairlyActive_mean', 
        'minutesLightlyActive_mean','sleep_mean_y', 
       'sleep_var_y']], ques_fitbit['positive_class']

# 学習データとテストデータを分ける
X_train, X_test, y_train, y_test = train_test_split(X, y)

# データを格納する
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# 学習条件を設定
params = {'task': 'train',
          'boosting_type': 'gbdt',
          'objective': 'multiclass',
          'metric': {'multi_logloss'},
          'num_class': 3,
          'learning_rate': 0.02,
          'num_leaves': 23,
          'min_data_in_leaf': 1,
          'num_iteration': 1000,
          'verbose': 0}

# 学習する
model = lgb.train(params,
                  lgb_train,
                  num_boost_round=50,
                  valid_sets=lgb_eval,
                  early_stopping_rounds=20)

# テストデータで予測する
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
y_pred_max = np.argmax(y_pred, axis=1)

# Accuracy を計算する
accuracy = sum(y_test == y_pred_max) / len(y_test)
print('accuracy:', accuracy)

# importanceを表示する
importance = pd.DataFrame(model.feature_importance(), index=list(X.columns), columns=['importance'])
display(importance)
importance.plot.bar()



# print('f1-score:',f1_score(y_test,y_pred_max))
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002898 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [1]	valid_0's multi_logloss: 1.09128
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's multi_logloss: 1.0843
# [3]	valid_0's multi_logloss: 1.07787
# [4]	valid_0's multi_logloss: 1.07169
# [5]	valid_0's multi_logloss: 1.06629
# [6]	valid_0's multi_logloss: 1.05969
# [7]	valid_0's multi_logloss: 1.05483
# [8]	valid_0's multi_logloss: 1.04963
# [9]	valid_0's multi_logloss: 1.04681
# [10]	valid_0's multi_logloss: 1.04332
# [11]	valid_0's multi_logloss: 1.03919
# [12]	valid_0's multi_logloss: 1.0349
# [13]	valid_0's multi_logloss: 1.03155
# [14]	valid_0's multi_logloss: 1.02745
# [15]	valid_0's multi_logloss: 1.02371
# [16]	valid_0's multi_logloss: 1.02043
# [17]	valid_0's multi_logloss: 1.01681
# [18]	valid_0's multi_logloss: 1.01371
# [19]	valid_0's multi_logloss: 1.01179
# [20]	valid_0's multi_logloss: 1.00932
# [21]	valid_0's multi_logloss: 1.00825
# [22]	valid_0's multi_logloss: 1.00699
# [23]	valid_0's multi_logloss: 1.00621
# [24]	valid_0's multi_logloss: 1.00489
# [25]	valid_0's multi_logloss: 1.00448
# [26]	valid_0's multi_logloss: 1.00251
# [27]	valid_0's multi_logloss: 1.00093
# [28]	valid_0's multi_logloss: 0.999412
# [29]	valid_0's multi_logloss: 0.998211
# [30]	valid_0's multi_logloss: 0.997353
# [31]	valid_0's multi_logloss: 0.996442
# [32]	valid_0's multi_logloss: 0.996316
# [33]	valid_0's multi_logloss: 0.994418
# [34]	valid_0's multi_logloss: 0.991982
# [35]	valid_0's multi_logloss: 0.991156
# [36]	valid_0's multi_logloss: 0.988384
# [37]	valid_0's multi_logloss: 0.987538
# [38]	valid_0's multi_logloss: 0.985271
# [39]	valid_0's multi_logloss: 0.983018
# [40]	valid_0's multi_logloss: 0.982274
# [41]	valid_0's multi_logloss: 0.981431
# [42]	valid_0's multi_logloss: 0.980453
# [43]	valid_0's multi_logloss: 0.981471
# [44]	valid_0's multi_logloss: 0.982503
# [45]	valid_0's multi_logloss: 0.983594
# [46]	valid_0's multi_logloss: 0.9824
# [47]	valid_0's multi_logloss: 0.982052
# [48]	valid_0's multi_logloss: 0.981347
# [49]	valid_0's multi_logloss: 0.982492
# [50]	valid_0's multi_logloss: 0.982233
# [51]	valid_0's multi_logloss: 0.98182
# [52]	valid_0's multi_logloss: 0.980994
# [53]	valid_0's multi_logloss: 0.980106
# [54]	valid_0's multi_logloss: 0.9793
# [55]	valid_0's multi_logloss: 0.978576
# [56]	valid_0's multi_logloss: 0.978065
# [57]	valid_0's multi_logloss: 0.977861
# [58]	valid_0's multi_logloss: 0.97828
# [59]	valid_0's multi_logloss: 0.978808
# [60]	valid_0's multi_logloss: 0.97854
# [61]	valid_0's multi_logloss: 0.978042
# [62]	valid_0's multi_logloss: 0.976199
# [63]	valid_0's multi_logloss: 0.976695
# [64]	valid_0's multi_logloss: 0.975927
# [65]	valid_0's multi_logloss: 0.977025
# [66]	valid_0's multi_logloss: 0.975427
# [67]	valid_0's multi_logloss: 0.975772
# [68]	valid_0's multi_logloss: 0.975513
# [69]	valid_0's multi_logloss: 0.975963
# [70]	valid_0's multi_logloss: 0.975196
# [71]	valid_0's multi_logloss: 0.976442
# [72]	valid_0's multi_logloss: 0.976047
# [73]	valid_0's multi_logloss: 0.975373
# [74]	valid_0's multi_logloss: 0.975039
# [75]	valid_0's multi_logloss: 0.975216
# [76]	valid_0's multi_logloss: 0.974015
# [77]	valid_0's multi_logloss: 0.975697
# [78]	valid_0's multi_logloss: 0.97652
# [79]	valid_0's multi_logloss: 0.976729
# [80]	valid_0's multi_logloss: 0.977315
# [81]	valid_0's multi_logloss: 0.976527
# [82]	valid_0's multi_logloss: 0.977191
# [83]	valid_0's multi_logloss: 0.978425
# [84]	valid_0's multi_logloss: 0.979901
# [85]	valid_0's multi_logloss: 0.980342
# [86]	valid_0's multi_logloss: 0.981502
# [87]	valid_0's multi_logloss: 0.981891
# [88]	valid_0's multi_logloss: 0.981512
# [89]	valid_0's multi_logloss: 0.982372
# [90]	valid_0's multi_logloss: 0.982246
# [91]	valid_0's multi_logloss: 0.982737
# [92]	valid_0's multi_logloss: 0.983243
# [93]	valid_0's multi_logloss: 0.983761
# [94]	valid_0's multi_logloss: 0.984417
# [95]	valid_0's multi_logloss: 0.984876
# [96]	valid_0's multi_logloss: 0.985891
# Early stopping, best iteration is:
# [76]	valid_0's multi_logloss: 0.974015
# accuracy: 0.5126050420168067
#                            importance
# user_id                           737
# floor_mean                        298
# floor_var                         170
# step_mean                         292
# step_var                          232
# mets_mean                         207
# calory_mean                       241
# mets_median                        79
# calory_median                     488
# mets_var                          163
# calory_var                        199
# heart_mean                        452
# heart_median                      200
# heart_var                         346
# minutesFairlyActive_mean          172
# minutesLightlyActive_mean         272
# sleep_mean_y                      266
# sleep_var_y                       202
# <AxesSubplot:>

# %%
cm = confusion_matrix(y_test, y_pred_max)
sns.heatmap(cm, annot=True, cmap='Blues').set(xlabel="predict label", ylabel="true label")
# Out:
# [Text(0.5, 12.5, 'predict label'), Text(30.5, 0.5, 'true label')]

# %%
ques_fitbit.to_csv('./analyse_data/ques_fitbit.csv')

# %%
ques_act_day.loc[ques_act_day['positive_score']<=2.666667,'positive_class']=0
ques_act_day.loc[(ques_act_day['positive_score']>2.666667)&(ques_act_day['positive_score']<4.66667),'positive_class']=1
ques_act_day.loc[ques_act_day['positive_score']>=4.66667,'positive_class']=2

ques_act_day.loc[ques_act_day['depressive_score']<=0.333333,'depressive_class']=0
ques_act_day.loc[(ques_act_day['depressive_score']>0.333333)&(ques_act_day['depressive_score']<2.666667),'depressive_class']=1
ques_act_day.loc[ques_act_day['depressive_score']>=2.666667,'depressive_class']=2

ques_act_day.loc[ques_act_day['anxious_score']<=0.666667,'anxious_class']=0
ques_act_day.loc[(ques_act_day['anxious_score']>0.666667)&(ques_act_day['anxious_score']<3.333333),'anxious_class']=1
ques_act_day.loc[ques_act_day['anxious_score']>=3.333333,'anxious_class']=2

# %%
ques_act_day_pred =ques_act_day[[  'user_id','meeting_ftof',  'meal', 'working_alone',
       'hobby_break', 'housework_childcare', 'break', 'transfer',
       'web_conference', 'other', 'work_outsideduty', 'facetoface_meeting',
       'collaboration', 'remote_conference',  'positive_class',
       'depressive_class', 'anxious_class']]

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
ques_act_day_pred['user_id'] = ques_act_day_pred['user_id'].astype('int')
X, y = ques_act_day_pred[['user_id',
        'meal', 'working_alone',
       'hobby_break', 'housework_childcare', 'break', 'transfer',
       'web_conference', 'other', 'work_outsideduty', 'facetoface_meeting',
       'collaboration', 'remote_conference']], ques_act_day_pred['positive_class']

# 学習データとテストデータを分ける
X_train, X_test, y_train, y_test = train_test_split(X, y)

# データを格納する
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# 学習条件を設定
params = {'task': 'train',
          'boosting_type': 'gbdt',
          'objective': 'multiclass',
          'metric': {'multi_logloss'},
          'num_class': 3,
          'learning_rate': 0.02,
          'num_leaves': 23,
          'min_data_in_leaf': 1,
          'num_iteration': 1000,
          'verbose': 0}

# 学習する
model = lgb.train(params,
                  lgb_train,
                  num_boost_round=50,
                  valid_sets=lgb_eval,
                  early_stopping_rounds=20)

# テストデータで予測する
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
y_pred_max = np.argmax(y_pred, axis=1)

# Accuracy を計算する
accuracy = sum(y_test == y_pred_max) / len(y_test)
print('accuracy:', accuracy)

# importanceを表示する
importance = pd.DataFrame(model.feature_importance(), index=list(X.columns), columns=['importance'])
display(importance)
importance.plot.bar()
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001392 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [1]	valid_0's multi_logloss: 1.0906
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's multi_logloss: 1.08418
# [3]	valid_0's multi_logloss: 1.07787
# [4]	valid_0's multi_logloss: 1.07191
# [5]	valid_0's multi_logloss: 1.06655
# [6]	valid_0's multi_logloss: 1.06169
# [7]	valid_0's multi_logloss: 1.0568
# [8]	valid_0's multi_logloss: 1.05161
# [9]	valid_0's multi_logloss: 1.04647
# [10]	valid_0's multi_logloss: 1.04179
# [11]	valid_0's multi_logloss: 1.03804
# [12]	valid_0's multi_logloss: 1.03391
# [13]	valid_0's multi_logloss: 1.03111
# [14]	valid_0's multi_logloss: 1.02689
# [15]	valid_0's multi_logloss: 1.02394
# [16]	valid_0's multi_logloss: 1.02117
# [17]	valid_0's multi_logloss: 1.01748
# [18]	valid_0's multi_logloss: 1.01495
# [19]	valid_0's multi_logloss: 1.01143
# [20]	valid_0's multi_logloss: 1.00851
# [21]	valid_0's multi_logloss: 1.00567
# [22]	valid_0's multi_logloss: 1.00332
# [23]	valid_0's multi_logloss: 1.00085
# [24]	valid_0's multi_logloss: 0.999093
# [25]	valid_0's multi_logloss: 0.997105
# [26]	valid_0's multi_logloss: 0.99479
# [27]	valid_0's multi_logloss: 0.993009
# [28]	valid_0's multi_logloss: 0.990726
# [29]	valid_0's multi_logloss: 0.988648
# [30]	valid_0's multi_logloss: 0.986574
# [31]	valid_0's multi_logloss: 0.985012
# [32]	valid_0's multi_logloss: 0.983766
# [33]	valid_0's multi_logloss: 0.981701
# [34]	valid_0's multi_logloss: 0.979609
# [35]	valid_0's multi_logloss: 0.977404
# [36]	valid_0's multi_logloss: 0.97539
# [37]	valid_0's multi_logloss: 0.974073
# [38]	valid_0's multi_logloss: 0.972686
# [39]	valid_0's multi_logloss: 0.970967
# [40]	valid_0's multi_logloss: 0.969133
# [41]	valid_0's multi_logloss: 0.967837
# [42]	valid_0's multi_logloss: 0.966633
# [43]	valid_0's multi_logloss: 0.965287
# [44]	valid_0's multi_logloss: 0.963729
# [45]	valid_0's multi_logloss: 0.962443
# [46]	valid_0's multi_logloss: 0.961286
# [47]	valid_0's multi_logloss: 0.960418
# [48]	valid_0's multi_logloss: 0.959868
# [49]	valid_0's multi_logloss: 0.959172
# [50]	valid_0's multi_logloss: 0.958419
# [51]	valid_0's multi_logloss: 0.95812
# [52]	valid_0's multi_logloss: 0.957377
# [53]	valid_0's multi_logloss: 0.956482
# [54]	valid_0's multi_logloss: 0.956158
# [55]	valid_0's multi_logloss: 0.956395
# [56]	valid_0's multi_logloss: 0.956422
# [57]	valid_0's multi_logloss: 0.955737
# [58]	valid_0's multi_logloss: 0.954729
# [59]	valid_0's multi_logloss: 0.954354
# [60]	valid_0's multi_logloss: 0.954096
# [61]	valid_0's multi_logloss: 0.954003
# [62]	valid_0's multi_logloss: 0.954747
# [63]	valid_0's multi_logloss: 0.954821
# [64]	valid_0's multi_logloss: 0.954749
# [65]	valid_0's multi_logloss: 0.954512
# [66]	valid_0's multi_logloss: 0.954403
# [67]	valid_0's multi_logloss: 0.953547
# [68]	valid_0's multi_logloss: 0.953234
# [69]	valid_0's multi_logloss: 0.95232
# [70]	valid_0's multi_logloss: 0.952609
# [71]	valid_0's multi_logloss: 0.95203
# [72]	valid_0's multi_logloss: 0.950406
# [73]	valid_0's multi_logloss: 0.950479
# [74]	valid_0's multi_logloss: 0.950441
# [75]	valid_0's multi_logloss: 0.950226
# [76]	valid_0's multi_logloss: 0.95064
# [77]	valid_0's multi_logloss: 0.950226
# [78]	valid_0's multi_logloss: 0.951023
# [79]	valid_0's multi_logloss: 0.951592
# [80]	valid_0's multi_logloss: 0.951231
# [81]	valid_0's multi_logloss: 0.95183
# [82]	valid_0's multi_logloss: 0.952146
# [83]	valid_0's multi_logloss: 0.952644
# [84]	valid_0's multi_logloss: 0.952401
# [85]	valid_0's multi_logloss: 0.952672
# [86]	valid_0's multi_logloss: 0.952249
# [87]	valid_0's multi_logloss: 0.952143
# [88]	valid_0's multi_logloss: 0.951882
# [89]	valid_0's multi_logloss: 0.952226
# [90]	valid_0's multi_logloss: 0.952056
# [91]	valid_0's multi_logloss: 0.951382
# [92]	valid_0's multi_logloss: 0.951784
# [93]	valid_0's multi_logloss: 0.951674
# [94]	valid_0's multi_logloss: 0.952093
# [95]	valid_0's multi_logloss: 0.952078
# [96]	valid_0's multi_logloss: 0.952498
# [97]	valid_0's multi_logloss: 0.952146
# Early stopping, best iteration is:
# [77]	valid_0's multi_logloss: 0.950226
# accuracy: 0.5578947368421052
#                      importance
# user_id                    1404
# meal                        501
# working_alone               692
# hobby_break                 589
# housework_childcare         273
# break                       360
# transfer                    383
# web_conference              335
# other                       227
# work_outsideduty             14
# facetoface_meeting          134
# collaboration               117
# remote_conference            53
# <AxesSubplot:>

# %%
# ques_act_day_pred.to_csv('./analyse_data/ques_act_day_pred.csv')

# %%
cm = confusion_matrix(y_test, y_pred_max)
sns.heatmap(cm, annot=True, cmap='Blues').set(xlabel="predict label", ylabel="true label")
# Out:
# [Text(0.5, 12.5, 'predict label'), Text(30.5, 0.5, 'true label')]

# %%
dams_score['Date_jp'] = pd.to_datetime(dams_score['Date_jp'])
att_weather_dams = pd.merge(dams_score, att_weather,left_on=['user_id','Date_jp'],right_on=['user_id','Date'])

# %%
att_weather_dams_pred = att_weather_dams[['user_id','positive_class',
       'depressive_class', 'anxious_class', 'sex', 'age', 'locate_id',
        'ave_temperature', 'max_temperature',
       'mini_temperature', 'sum_rainfall', 'sunlight_time', 'ave_windspeed',
       'max_windspeed', 'ave_vaporpressure', 'ave_cloudcover', 'weather_6to18',
       'weather_18to6']]

# %%
att_weather_dams.columns
# Out:
# Index(['user_id', 'value_dams', 'datetime_jp', 'Date_jp', 'positive_score',
#        'depressive_score', 'anxious_score', 'Days_plus1', 'positive_class',
#        'depressive_class', 'anxious_class', 'sex', 'age', 'locate_id',
#        'locate_name', 'Date', 'ave_temperature', 'max_temperature',
#        'mini_temperature', 'sum_rainfall', 'sunlight_time', 'ave_windspeed',
#        'max_windspeed', 'ave_vaporpressure', 'ave_cloudcover', 'weather_6to18',
#        'weather_18to6', 'locate'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
att_weather_dams_pred[['user_id','sex', 'age', 'weather_6to18',
       'weather_18to6']]=att_weather_dams_pred[['user_id','sex', 'age', 'weather_6to18',
       'weather_18to6']].astype('int')
X, y = att_weather_dams_pred[['user_id', 'sex', 'age', 
        'ave_temperature', 'max_temperature',
       'mini_temperature', 'sum_rainfall', 'sunlight_time', 'ave_windspeed',
       'max_windspeed', 'ave_vaporpressure', 'ave_cloudcover', 'weather_6to18',
       'weather_18to6']], att_weather_dams_pred['positive_class']

# 学習データとテストデータを分ける
X_train, X_test, y_train, y_test = train_test_split(X, y)

# データを格納する
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# 学習条件を設定
params = {'task': 'train',
          'boosting_type': 'gbdt',
          'objective': 'multiclass',
          'metric': {'multi_logloss'},
          'num_class': 3,
          'learning_rate': 0.02,
          'num_leaves': 23,
          'min_data_in_leaf': 1,
          'num_iteration': 1000,
          'verbose': 0}

# 学習する
model = lgb.train(params,
                  lgb_train,
                  num_boost_round=50,
                  valid_sets=lgb_eval,
                  early_stopping_rounds=20,
#                   categorical_feature = att_weather_dams_pred[[ 'sex', 'age', 'weather_6to18','weather_18to6']]
                 )

# テストデータで予測する
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
y_pred_max = np.argmax(y_pred, axis=1)

# Accuracy を計算する
accuracy = sum(y_test == y_pred_max) / len(y_test)
print('accuracy:', accuracy)

# importanceを表示する
importance = pd.DataFrame(model.feature_importance(), index=list(X.columns), columns=['importance'])
display(importance)
importance.plot.bar()
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003358 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [1]	valid_0's multi_logloss: 1.09364
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's multi_logloss: 1.08737
# [3]	valid_0's multi_logloss: 1.08149
# [4]	valid_0's multi_logloss: 1.076
# [5]	valid_0's multi_logloss: 1.07078
# [6]	valid_0's multi_logloss: 1.06617
# [7]	valid_0's multi_logloss: 1.06174
# [8]	valid_0's multi_logloss: 1.05713
# [9]	valid_0's multi_logloss: 1.05266
# [10]	valid_0's multi_logloss: 1.04917
# [11]	valid_0's multi_logloss: 1.04493
# [12]	valid_0's multi_logloss: 1.04082
# [13]	valid_0's multi_logloss: 1.03704
# [14]	valid_0's multi_logloss: 1.03351
# [15]	valid_0's multi_logloss: 1.03025
# [16]	valid_0's multi_logloss: 1.02713
# [17]	valid_0's multi_logloss: 1.02388
# [18]	valid_0's multi_logloss: 1.02124
# [19]	valid_0's multi_logloss: 1.01835
# [20]	valid_0's multi_logloss: 1.0151
# [21]	valid_0's multi_logloss: 1.01217
# [22]	valid_0's multi_logloss: 1.00974
# [23]	valid_0's multi_logloss: 1.00648
# [24]	valid_0's multi_logloss: 1.00353
# [25]	valid_0's multi_logloss: 1.00048
# [26]	valid_0's multi_logloss: 0.997699
# [27]	valid_0's multi_logloss: 0.996343
# [28]	valid_0's multi_logloss: 0.993624
# [29]	valid_0's multi_logloss: 0.992495
# [30]	valid_0's multi_logloss: 0.989894
# [31]	valid_0's multi_logloss: 0.987341
# [32]	valid_0's multi_logloss: 0.985936
# [33]	valid_0's multi_logloss: 0.983463
# [34]	valid_0's multi_logloss: 0.982181
# [35]	valid_0's multi_logloss: 0.979875
# [36]	valid_0's multi_logloss: 0.978609
# [37]	valid_0's multi_logloss: 0.976496
# [38]	valid_0's multi_logloss: 0.974164
# [39]	valid_0's multi_logloss: 0.972363
# [40]	valid_0's multi_logloss: 0.970351
# [41]	valid_0's multi_logloss: 0.968549
# [42]	valid_0's multi_logloss: 0.966297
# [43]	valid_0's multi_logloss: 0.965181
# [44]	valid_0's multi_logloss: 0.963426
# [45]	valid_0's multi_logloss: 0.96195
# [46]	valid_0's multi_logloss: 0.960549
# [47]	valid_0's multi_logloss: 0.959334
# [48]	valid_0's multi_logloss: 0.95773
# [49]	valid_0's multi_logloss: 0.957582
# [50]	valid_0's multi_logloss: 0.956812
# [51]	valid_0's multi_logloss: 0.955537
# [52]	valid_0's multi_logloss: 0.954904
# [53]	valid_0's multi_logloss: 0.953981
# [54]	valid_0's multi_logloss: 0.95314
# [55]	valid_0's multi_logloss: 0.952408
# [56]	valid_0's multi_logloss: 0.95158
# [57]	valid_0's multi_logloss: 0.951506
# [58]	valid_0's multi_logloss: 0.950497
# [59]	valid_0's multi_logloss: 0.950052
# [60]	valid_0's multi_logloss: 0.949172
# [61]	valid_0's multi_logloss: 0.94837
# [62]	valid_0's multi_logloss: 0.946855
# [63]	valid_0's multi_logloss: 0.946418
# [64]	valid_0's multi_logloss: 0.945731
# [65]	valid_0's multi_logloss: 0.944372
# [66]	valid_0's multi_logloss: 0.943596
# [67]	valid_0's multi_logloss: 0.942891
# [68]	valid_0's multi_logloss: 0.942289
# [69]	valid_0's multi_logloss: 0.94184
# [70]	valid_0's multi_logloss: 0.940683
# [71]	valid_0's multi_logloss: 0.940066
# [72]	valid_0's multi_logloss: 0.939104
# [73]	valid_0's multi_logloss: 0.937585
# [74]	valid_0's multi_logloss: 0.9363
# [75]	valid_0's multi_logloss: 0.935647
# [76]	valid_0's multi_logloss: 0.935382
# [77]	valid_0's multi_logloss: 0.934387
# [78]	valid_0's multi_logloss: 0.934062
# [79]	valid_0's multi_logloss: 0.933951
# [80]	valid_0's multi_logloss: 0.933004
# [81]	valid_0's multi_logloss: 0.932885
# [82]	valid_0's multi_logloss: 0.932354
# [83]	valid_0's multi_logloss: 0.931665
# [84]	valid_0's multi_logloss: 0.93198
# [85]	valid_0's multi_logloss: 0.932457
# [86]	valid_0's multi_logloss: 0.932707
# [87]	valid_0's multi_logloss: 0.933254
# [88]	valid_0's multi_logloss: 0.933738
# [89]	valid_0's multi_logloss: 0.933866
# [90]	valid_0's multi_logloss: 0.933548
# [91]	valid_0's multi_logloss: 0.933379
# [92]	valid_0's multi_logloss: 0.933639
# [93]	valid_0's multi_logloss: 0.933967
# [94]	valid_0's multi_logloss: 0.933631
# [95]	valid_0's multi_logloss: 0.932308
# [96]	valid_0's multi_logloss: 0.931355
# [97]	valid_0's multi_logloss: 0.930857
# [98]	valid_0's multi_logloss: 0.930066
# [99]	valid_0's multi_logloss: 0.929761
# [100]	valid_0's multi_logloss: 0.92922
# [101]	valid_0's multi_logloss: 0.928178
# [102]	valid_0's multi_logloss: 0.928421
# [103]	valid_0's multi_logloss: 0.928067
# [104]	valid_0's multi_logloss: 0.927716
# [105]	valid_0's multi_logloss: 0.926482
# [106]	valid_0's multi_logloss: 0.926349
# [107]	valid_0's multi_logloss: 0.926037
# [108]	valid_0's multi_logloss: 0.926093
# [109]	valid_0's multi_logloss: 0.925612
# [110]	valid_0's multi_logloss: 0.925496
# [111]	valid_0's multi_logloss: 0.925582
# [112]	valid_0's multi_logloss: 0.924615
# [113]	valid_0's multi_logloss: 0.924769
# [114]	valid_0's multi_logloss: 0.924746
# [115]	valid_0's multi_logloss: 0.924196
# [116]	valid_0's multi_logloss: 0.923819
# [117]	valid_0's multi_logloss: 0.923629
# [118]	valid_0's multi_logloss: 0.923918
# [119]	valid_0's multi_logloss: 0.923839
# [120]	valid_0's multi_logloss: 0.923961
# [121]	valid_0's multi_logloss: 0.924463
# [122]	valid_0's multi_logloss: 0.924464
# [123]	valid_0's multi_logloss: 0.92466
# [124]	valid_0's multi_logloss: 0.925205
# [125]	valid_0's multi_logloss: 0.925701
# [126]	valid_0's multi_logloss: 0.924925
# [127]	valid_0's multi_logloss: 0.925493
# [128]	valid_0's multi_logloss: 0.925894
# [129]	valid_0's multi_logloss: 0.925798
# [130]	valid_0's multi_logloss: 0.926079
# [131]	valid_0's multi_logloss: 0.925756
# [132]	valid_0's multi_logloss: 0.92627
# [133]	valid_0's multi_logloss: 0.926543
# [134]	valid_0's multi_logloss: 0.926937
# [135]	valid_0's multi_logloss: 0.927093
# [136]	valid_0's multi_logloss: 0.927512
# [137]	valid_0's multi_logloss: 0.9282
# Early stopping, best iteration is:
# [117]	valid_0's multi_logloss: 0.923629
# accuracy: 0.5677655677655677
#                    importance
# user_id                  2311
# sex                       211
# age                      1183
# ave_temperature           616
# max_temperature           412
# mini_temperature          648
# sum_rainfall              206
# sunlight_time             414
# ave_windspeed             356
# max_windspeed             546
# ave_vaporpressure         333
# ave_cloudcover            454
# weather_6to18              10
# weather_18to6              22
# <AxesSubplot:>

# %%
cm = confusion_matrix(y_test, y_pred_max)
sns.heatmap(cm, annot=True, cmap='Blues').set(xlabel="predict label", ylabel="true label")
# Out:
# [Text(0.5, 12.5, 'predict label'), Text(30.5, 0.5, 'true label')]

# %%
# att_weather_dams_pred.to_csv('./analyse_data/att_weather_dams_pred.csv')

# %%
'positive_score_label_m', 'depressive_score_label_m',
       'anxious_score_label_m', 'value_nemuke', 'value_hukai', 'value_boyake',
       'value_nemuke_label_m', 'value_hukai_label_m', 'value_boyake_label_m',
       'merge_date', 'positive_score_label_y',
       'depressive_score_label_y', 'anxious_score_label_y',
       'value_hukai_label_y', 'value_boyake_label_y', 'value_nemuke_label_y',
        'value_eval_label', 'hour', 'kouritu_label', 'syutyu_label',
       'yoteidori_label', 'jubun_comu_label', 'kouritu_comu_label',
       'idea_label', 'seika_label', 'study_new_label',
       'decide_doing_label', 'paformance_label', 'absent_by_problem_label',
        'value_recover_label',
       'workenga_score_label']

# %%
import pandas as pd
all_data = pd.read_csv('./all_data.csv')
night_w_recover = pd.read_csv('./analyse_data/questionaire_data/night_w_recover.csv')
night_w_workenga = pd.read_csv('./analyse_data/questionaire_data/night_w_workenga.csv')
night_w_productivity = pd.read_csv('./analyse_data/questionaire_data/night_w_productivity.csv')

# %%
night_w_recover = night_w_recover[[ 'user_id', 'value_recover', 'forget_work', 'relax',
       'date']]

# %%
recover_cont = night_w_productivity[[ 'user_id','date', 'decide_doing','study_new']]
night_w_recover = pd.merge(night_w_recover, recover_cont,on=['user_id','date'])

# %%
night_w_recover['value_recover'] = (night_w_recover['forget_work']+
                                   night_w_recover['relax']+
                                   night_w_recover['decide_doing']+
                                   night_w_recover['study_new'])/4

# %%
night_w_recover['value_recover']
# Out:
# 0       3.25
# 1       3.00
# 2       3.25
# 3       2.50
# 4       2.00
#         ...
# 1044    3.25
# 1045    2.50
# 1046    4.25
# 1047    2.00
# 1048    2.50
# Name: value_recover, Length: 1049, dtype: float64

# %%
#目的変数のラベルづけ
#下位40%と上位40％の二値分類をする
def labeling(df, colmn):
    under_40 = df[colmn].quantile(0.4)
    upper_60 = df[colmn].quantile(0.6)
    df.loc[df[colmn]<=under_40,colmn + '_label']=0
    df.loc[df[colmn]>=upper_60,colmn + '_label']=2
    df.loc[(df[colmn]<upper_60)&(df[colmn]>under_40),colmn + '_label']=1
    df = df.dropna(subset=[colmn])
    return df

# %%
labeling(night_w_recover, 'value_recover')
recover_label = night_w_recover[['date','user_id','value_recover_label']]

# %%
all_data=all_data.drop(columns=['decide_doing_label','study_new_label'])

# %%
all_data = pd.merge(all_data, recover_label, on=['user_id','date'])

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn import datasets
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score # モデル評価用(正答率)
from sklearn.metrics import log_loss # モデル評価用(logloss)     
from sklearn.metrics import roc_auc_score # モデル評価用(auc)
import japanize_matplotlib
# ques_act_day_pred['user_id'] = ques_act_day_pred['user_id'].astype('int')
target = 'positive_score_label_m'

all_data_pre=all_data[all_data[target]!=1].dropna(subset=[target])
X = all_data_pre[[
        '管理者兼作業者', '企画業務', 'ノンコア業務（自身が本来担当ではない業務）', '管理者',
       '比較的慣れており，定型化できている業務', 'コア業務（自身が本来担当している業務）', '共同作業者', '開発業務', '管理業務',
       '作業者/参加者', '管理の業務', '比較的新規性が高く，試行錯誤を伴う定型化できていない業務', '営業業務',
       '事務業務（サポート業務、経理業務など）', '現場業務（主に肉体労働を伴うもの）', '現場（主に肉体労働を伴うもの）', '家（その他）',
       'どちらでもない', '一人', '家（書斎など執務向けの場所）', '他者あり（同僚など）', '家（リビングなど）', '快適',
       '職場外のワークスペース', '他者あり（無干渉）', '他者あり（同僚）', '職場', '他者あり（家族など）', '店/外', '不快',
       '非常に快適', '職場外ワークスペース', '非常に不快',
                 
#         '対面会議', '食事', '単独作業', '趣味・休憩', '家事・育児', '休憩（業務時間内）',
#        '移動', 'web会議', 'その他', '業務外作業', '共同作業（コミュニケーションを伴う）', '電話（会議）',
    ]]
y = all_data_pre[target].replace(2,1).astype('int')

 # kfoldの分割数
k = 5
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=0)
# 学習条件を設定
params = {'task': 'train',
              'boosting_type': 'gbdt',
              'objective': 'binary',
              'metric': {'binary_error'},
              'num_class': 1,
              'learning_rate': 0.02,
              'num_leaves': 23,
              'min_data_in_leaf': 1,
              'num_iteration': 1000,
              'verbose': 0,
              'reg_alpha':0.93,
              'reg_lambda':2.3
              }
    
acc_list = []
f1_list = []
auc_list = []
    
for train_index, test_index in skf.split(X, y):
    X_train = X.iloc[train_index]
    y_train = y.iloc[train_index]
    X_test = X.iloc[test_index]
    y_test = y.iloc[test_index]
        
    # ここではvalidをモデル評価、evalをフォールドアウト検証に使う・・・分割の大きさはデータセットと相談する
    X_eval, X_valid, y_eval, y_valid = train_test_split(X_test, y_test, random_state=90, 
                                                            shuffle=True, stratify=y_test, test_size=0.3)
    # データセットを生成する
    lgb_train = lgb.Dataset(X_train, y_train)

    # モデル評価用
    lgb_valid = lgb.Dataset(X_valid, y_valid, reference=lgb_train)
    # 学習する
    model = lgb.train(params,
                          lgb_train,
                          num_boost_round=50,
                          valid_sets=lgb_valid,
                          early_stopping_rounds=20)
        
    y_pred_prob = model.predict(X_test, num_iteration=model.best_iteration)
    y_pred = [0 if i < 0.5 else 1 for i in y_pred_prob]
        
    # acc : 正答率
    acc = accuracy_score(y_test,y_pred)
    print('Acc :', acc)
    # f1-score
    f1 = f1_score(y_test,y_pred)
    print('f1-score :', f1)
    # logloss 
    logloss =  log_loss(y_test,y_pred_prob) # 引数 : log_loss(正解クラス,[クラス0の予測確率,クラス1の予測確率])
    print('logloss :', logloss)
    # AUC 
    auc = roc_auc_score(y_test,y_pred_prob) # 引数 : roc_auc_score(正解クラス, クラス1の予測確率)
    print('AUC :', auc) 
        
    acc_list.append(acc)
    f1_list.append(f1)
    auc_list.append(auc)
        
print('Kfold平均 acc:{}, f1-score:{}, auc:{}'.format(np.mean(acc_list), 
                                                         np.mean(f1_list), 
                                                         np.mean(auc_list)))
column = 'importance_'+ target
# importanceを表示する
importance = pd.DataFrame(model.feature_importance(importance_type='gain'), index=list(X.columns), columns=[column])
display(importance.sort_values(column, ascending=False))
good_columns=importance.sort_values(column, ascending=False).index[0:30]
importance.plot.bar()
# Out:
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003246 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [1]	valid_0's binary_error: 0.418605
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.418605
# [3]	valid_0's binary_error: 0.418605
# [4]	valid_0's binary_error: 0.418605
# [5]	valid_0's binary_error: 0.418605
# [6]	valid_0's binary_error: 0.418605
# [7]	valid_0's binary_error: 0.418605
# [8]	valid_0's binary_error: 0.418605
# [9]	valid_0's binary_error: 0.372093
# [10]	valid_0's binary_error: 0.325581
# [11]	valid_0's binary_error: 0.27907
# [12]	valid_0's binary_error: 0.27907
# [13]	valid_0's binary_error: 0.27907
# [14]	valid_0's binary_error: 0.209302
# [15]	valid_0's binary_error: 0.209302
# [16]	valid_0's binary_error: 0.209302
# [17]	valid_0's binary_error: 0.209302
# [18]	valid_0's binary_error: 0.209302
# [19]	valid_0's binary_error: 0.209302
# [20]	valid_0's binary_error: 0.209302
# [21]	valid_0's binary_error: 0.209302
# [22]	valid_0's binary_error: 0.209302
# [23]	valid_0's binary_error: 0.232558
# [24]	valid_0's binary_error: 0.232558
# [25]	valid_0's binary_error: 0.232558
# [26]	valid_0's binary_error: 0.232558
# [27]	valid_0's binary_error: 0.232558
# [28]	valid_0's binary_error: 0.209302
# [29]	valid_0's binary_error: 0.209302
# [30]	valid_0's binary_error: 0.209302
# [31]	valid_0's binary_error: 0.209302
# [32]	valid_0's binary_error: 0.209302
# [33]	valid_0's binary_error: 0.209302
# [34]	valid_0's binary_error: 0.209302
# Early stopping, best iteration is:
# [14]	valid_0's binary_error: 0.209302
# Acc : 0.8085106382978723
# f1-score : 0.8540540540540541
# logloss : 0.5933041424381709
# AUC : 0.8362139917695472
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004518 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [1]	valid_0's binary_error: 0.418605
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.418605
# [3]	valid_0's binary_error: 0.418605
# [4]	valid_0's binary_error: 0.418605
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [5]	valid_0's binary_error: 0.418605
# [6]	valid_0's binary_error: 0.418605
# [7]	valid_0's binary_error: 0.418605
# [8]	valid_0's binary_error: 0.418605
# [9]	valid_0's binary_error: 0.418605
# [10]	valid_0's binary_error: 0.418605
# [11]	valid_0's binary_error: 0.27907
# [12]	valid_0's binary_error: 0.186047
# [13]	valid_0's binary_error: 0.186047
# [14]	valid_0's binary_error: 0.186047
# [15]	valid_0's binary_error: 0.186047
# [16]	valid_0's binary_error: 0.186047
# [17]	valid_0's binary_error: 0.186047
# [18]	valid_0's binary_error: 0.186047
# [19]	valid_0's binary_error: 0.209302
# [20]	valid_0's binary_error: 0.209302
# [21]	valid_0's binary_error: 0.209302
# [22]	valid_0's binary_error: 0.209302
# [23]	valid_0's binary_error: 0.209302
# [24]	valid_0's binary_error: 0.209302
# [25]	valid_0's binary_error: 0.209302
# [26]	valid_0's binary_error: 0.209302
# [27]	valid_0's binary_error: 0.209302
# [28]	valid_0's binary_error: 0.209302
# [29]	valid_0's binary_error: 0.209302
# [30]	valid_0's binary_error: 0.209302
# [31]	valid_0's binary_error: 0.209302
# [32]	valid_0's binary_error: 0.209302
# Early stopping, best iteration is:
# [12]	valid_0's binary_error: 0.186047
# Acc : 0.8368794326241135
# f1-score : 0.8685714285714285
# logloss : 0.5939607754051953
# AUC : 0.8763374485596707
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003205 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [1]	valid_0's binary_error: 0.418605
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.418605
# [3]	valid_0's binary_error: 0.418605
# [4]	valid_0's binary_error: 0.418605
# [5]	valid_0's binary_error: 0.418605
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [6]	valid_0's binary_error: 0.418605
# [7]	valid_0's binary_error: 0.418605
# [8]	valid_0's binary_error: 0.418605
# [9]	valid_0's binary_error: 0.418605
# [10]	valid_0's binary_error: 0.116279
# [11]	valid_0's binary_error: 0.116279
# [12]	valid_0's binary_error: 0.0930233
# [13]	valid_0's binary_error: 0.0697674
# [14]	valid_0's binary_error: 0.0930233
# [15]	valid_0's binary_error: 0.0930233
# [16]	valid_0's binary_error: 0.0930233
# [17]	valid_0's binary_error: 0.0930233
# [18]	valid_0's binary_error: 0.0930233
# [19]	valid_0's binary_error: 0.0930233
# [20]	valid_0's binary_error: 0.0930233
# [21]	valid_0's binary_error: 0.0930233
# [22]	valid_0's binary_error: 0.0697674
# [23]	valid_0's binary_error: 0.0930233
# [24]	valid_0's binary_error: 0.0697674
# [25]	valid_0's binary_error: 0.0697674
# [26]	valid_0's binary_error: 0.0697674
# [27]	valid_0's binary_error: 0.0697674
# [28]	valid_0's binary_error: 0.0697674
# [29]	valid_0's binary_error: 0.0697674
# [30]	valid_0's binary_error: 0.0697674
# [31]	valid_0's binary_error: 0.0697674
# [32]	valid_0's binary_error: 0.0697674
# [33]	valid_0's binary_error: 0.0697674
# Early stopping, best iteration is:
# [13]	valid_0's binary_error: 0.0697674
# Acc : 0.8226950354609929
# f1-score : 0.8603351955307262
# logloss : 0.5825744514125741
# AUC : 0.9011316872427984
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001296 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [1]	valid_0's binary_error: 0.418605
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.418605
# [3]	valid_0's binary_error: 0.418605
# [4]	valid_0's binary_error: 0.418605
# [5]	valid_0's binary_error: 0.418605
# [6]	valid_0's binary_error: 0.418605
# [7]	valid_0's binary_error: 0.418605
# [8]	valid_0's binary_error: 0.418605
# [9]	valid_0's binary_error: 0.162791
# [10]	valid_0's binary_error: 0.162791
# [11]	valid_0's binary_error: 0.139535
# [12]	valid_0's binary_error: 0.139535
# [13]	valid_0's binary_error: 0.139535
# [14]	valid_0's binary_error: 0.139535
# [15]	valid_0's binary_error: 0.116279
# [16]	valid_0's binary_error: 0.116279
# [17]	valid_0's binary_error: 0.116279
# [18]	valid_0's binary_error: 0.139535
# [19]	valid_0's binary_error: 0.162791
# [20]	valid_0's binary_error: 0.139535
# [21]	valid_0's binary_error: 0.162791
# [22]	valid_0's binary_error: 0.162791
# [23]	valid_0's binary_error: 0.162791
# [24]	valid_0's binary_error: 0.162791
# [25]	valid_0's binary_error: 0.162791
# [26]	valid_0's binary_error: 0.162791
# [27]	valid_0's binary_error: 0.162791
# [28]	valid_0's binary_error: 0.162791
# [29]	valid_0's binary_error: 0.162791
# [30]	valid_0's binary_error: 0.162791
# [31]	valid_0's binary_error: 0.162791
# [32]	valid_0's binary_error: 0.139535
# [33]	valid_0's binary_error: 0.139535
# [34]	valid_0's binary_error: 0.139535
# [35]	valid_0's binary_error: 0.139535
# Early stopping, best iteration is:
# [15]	valid_0's binary_error: 0.116279
# Acc : 0.8085106382978723
# f1-score : 0.8457142857142856
# logloss : 0.5832024149168413
# AUC : 0.856687242798354
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000491 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's binary_error: 0.428571
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.428571
# [3]	valid_0's binary_error: 0.428571
# [4]	valid_0's binary_error: 0.428571
# [5]	valid_0's binary_error: 0.428571
# [6]	valid_0's binary_error: 0.428571
# [7]	valid_0's binary_error: 0.428571
# [8]	valid_0's binary_error: 0.428571
# [9]	valid_0's binary_error: 0.190476
# [10]	valid_0's binary_error: 0.190476
# [11]	valid_0's binary_error: 0.190476
# [12]	valid_0's binary_error: 0.190476
# [13]	valid_0's binary_error: 0.190476
# [14]	valid_0's binary_error: 0.190476
# [15]	valid_0's binary_error: 0.190476
# [16]	valid_0's binary_error: 0.166667
# [17]	valid_0's binary_error: 0.142857
# [18]	valid_0's binary_error: 0.166667
# [19]	valid_0's binary_error: 0.166667
# [20]	valid_0's binary_error: 0.142857
# [21]	valid_0's binary_error: 0.142857
# [22]	valid_0's binary_error: 0.119048
# [23]	valid_0's binary_error: 0.142857
# [24]	valid_0's binary_error: 0.119048
# [25]	valid_0's binary_error: 0.119048
# [26]	valid_0's binary_error: 0.119048
# [27]	valid_0's binary_error: 0.119048
# [28]	valid_0's binary_error: 0.119048
# [29]	valid_0's binary_error: 0.119048
# [30]	valid_0's binary_error: 0.119048
# [31]	valid_0's binary_error: 0.119048
# [32]	valid_0's binary_error: 0.119048
# [33]	valid_0's binary_error: 0.119048
# [34]	valid_0's binary_error: 0.119048
# [35]	valid_0's binary_error: 0.119048
# [36]	valid_0's binary_error: 0.119048
# [37]	valid_0's binary_error: 0.119048
# [38]	valid_0's binary_error: 0.0952381
# [39]	valid_0's binary_error: 0.119048
# [40]	valid_0's binary_error: 0.0952381
# [41]	valid_0's binary_error: 0.0952381
# [42]	valid_0's binary_error: 0.0952381
# [43]	valid_0's binary_error: 0.119048
# [44]	valid_0's binary_error: 0.119048
# [45]	valid_0's binary_error: 0.119048
# [46]	valid_0's binary_error: 0.119048
# [47]	valid_0's binary_error: 0.119048
# [48]	valid_0's binary_error: 0.119048
# [49]	valid_0's binary_error: 0.119048
# [50]	valid_0's binary_error: 0.119048
# [51]	valid_0's binary_error: 0.119048
# [52]	valid_0's binary_error: 0.119048
# [53]	valid_0's binary_error: 0.119048
# [54]	valid_0's binary_error: 0.119048
# [55]	valid_0's binary_error: 0.119048
# [56]	valid_0's binary_error: 0.142857
# [57]	valid_0's binary_error: 0.142857
# [58]	valid_0's binary_error: 0.142857
# Early stopping, best iteration is:
# [38]	valid_0's binary_error: 0.0952381
# Acc : 0.8071428571428572
# f1-score : 0.8491620111731844
# logloss : 0.48548764419830165
# AUC : 0.9197530864197531
# Kfold平均 acc:0.8167477203647417, f1-score:0.8555673950087357, auc:0.8780246913580246
#                               importance_positive_score_label_m
# 作業者/参加者                                             1405.998990
# 快適                                                  1114.044295
# 他者あり（同僚など）                                           836.102247
# 比較的新規性が高く，試行錯誤を伴う定型化できていない業務                         445.668675
# 家（その他）                                               399.167286
# どちらでもない                                              383.273361
# 家（リビングなど）                                            362.104051
# 比較的慣れており，定型化できている業務                                  289.335481
# 不快                                                   259.495997
# 職場                                                   205.954163
# 現場業務（主に肉体労働を伴うもの）                                    180.481631
# ノンコア業務（自身が本来担当ではない業務）                                167.764851
# 非常に快適                                                154.013659
# コア業務（自身が本来担当している業務）                                  119.580759
# 開発業務                                                 103.623150
# 事務業務（サポート業務、経理業務など）                                   85.883421
# 職場外のワークスペース                                           70.582480
# 共同作業者                                                 68.461440
# 営業業務                                                  67.580400
# 企画業務                                                  53.614990
# 管理者                                                   53.160400
# 管理業務                                                  47.314100
# 家（書斎など執務向けの場所）                                        40.305650
# 店/外                                                   31.675010
# 管理者兼作業者                                               26.904650
# 他者あり（無干渉）                                             26.045700
# 一人                                                    23.602010
# 他者あり（同僚）                                               0.000000
# 他者あり（家族など）                                             0.000000
# 現場（主に肉体労働を伴うもの）                                        0.000000
# 管理の業務                                                  0.000000
# 職場外ワークスペース                                             0.000000
# 非常に不快                                                  0.000000
# <AxesSubplot:>
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 31649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 29702 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 32773 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20860 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20316 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20225 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 30011 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21209 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12494 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12531 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12467 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 33258 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 36523 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25285 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24403 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12391 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12399 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12394 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 36611 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 30340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24931 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12390 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12362 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12426 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 65292 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 23450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22411 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12365 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12427 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12375 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20849 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 38283 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 30330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21442 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 35215 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24615 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12367 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 35430 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 34892 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 37679 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 35492 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12434 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20276 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12358 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21942 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20107 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 32076 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12393 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 29694 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22580 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20027 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12395 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 32905 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20307 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21172 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20685 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12418 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12381 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20182 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12385 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12425 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 19968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26360 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25998 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22519 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21521 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12369 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12354 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20698 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12522 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12499 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 36969 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 32887 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22806 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12527 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12463 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12506 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 28961 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 28169 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26063 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24215 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 19981 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 38750 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 31649 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 29702 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 32773 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20860 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20316 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26989 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20225 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 30011 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21209 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12494 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12531 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12467 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12450 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 33258 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 36523 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26469 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25285 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24403 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12391 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12399 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12394 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 36611 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 30340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24931 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12390 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12362 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12426 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 65292 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 23450 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22411 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12365 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12427 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12375 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20849 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 38283 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 30330 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21442 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 35215 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24615 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12367 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 35430 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 34892 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 37679 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 35492 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12434 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20276 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12358 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21942 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20107 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12509 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 32076 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12393 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 29694 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22580 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20027 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12395 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 32905 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20307 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21172 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20685 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12418 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12381 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20182 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12385 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12425 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 19968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26360 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25998 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22519 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21521 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12369 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12354 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20698 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12522 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12499 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 36969 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 32887 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22806 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12527 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12463 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12506 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 28961 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24178 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 28169 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26063 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24215 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 19981 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 38750 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24120 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# all_importance = pd.merge(all_importance, importance,left_index=True, right_index=True)
all_importance_detail = all_importance[['importance_positive_score_label_m_x',
       'importance_depressive_score_label_m',
       'importance_anxious_score_label_m', 'importance_positive_score_label_y',
       'importance_depressive_score_label_y',
       'importance_anxious_score_label_y']].rename(columns={'importance_positive_score_label_m_x':'importance_positive_score_label_morning'
                                                           ,'importance_depressive_score_label_m':'importance_depressive_score_label_morning'
                                                           ,'importance_anxious_score_label_m':'importance_anxious_score_label_morning'
                                                           ,'importance_positive_score_label_y':'importance_positive_score_label_night'
                                                           ,'importance_depressive_score_label_y':'importance_depressive_score_label_night'
                                                           ,'importance_anxious_score_label_y':'importance_anxious_score_label_night'})
# all_importance = pd.merge(all_importance, importance,left_index=True, right_index=True)
# all_importance

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score # モデル評価用(正答率)
from sklearn.metrics import log_loss # モデル評価用(logloss)     
from sklearn.metrics import roc_auc_score # モデル評価用(auc)
import japanize_matplotlib
# ques_act_day_pred['user_id'] = ques_act_day_pred['user_id'].astype('int')
target='value_recover_label_y'
all_data_pre=all_data[all_data[target]!=1].dropna(subset=[target])
X = all_data_pre[good_columns]
y = all_data_pre[target].replace(2,1).astype('int')

 # kfoldの分割数
k = 5
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=0)
# 学習条件を設定
params = {'task': 'train',
              'boosting_type': 'gbdt',
              'objective': 'binary',
              'metric': {'binary_error'},
              'num_class': 1,
              'learning_rate': 0.02,
              'num_leaves': 23,
              'min_data_in_leaf': 1,
              'num_iteration': 1000,
              'verbose': 0,
              'reg_alpha':0.93,
              'reg_lambda':2.3
              }
    
acc_list = []
f1_list = []
auc_list = []
    
for train_index, test_index in skf.split(X, y):
    X_train = X.iloc[train_index]
    y_train = y.iloc[train_index]
    X_test = X.iloc[test_index]
    y_test = y.iloc[test_index]
        
    # ここではvalidをモデル評価、evalをフォールドアウト検証に使う・・・分割の大きさはデータセットと相談する
    X_eval, X_valid, y_eval, y_valid = train_test_split(X_test, y_test, random_state=90, 
                                                            shuffle=True, stratify=y_test, test_size=0.3)
    # データセットを生成する
    lgb_train = lgb.Dataset(X_train, y_train)

    # モデル評価用
    lgb_valid = lgb.Dataset(X_valid, y_valid, reference=lgb_train)
    # 学習する
    model = lgb.train(params,
                          lgb_train,
                          num_boost_round=50,
                          valid_sets=lgb_valid,
                          early_stopping_rounds=20)
        
    y_pred_prob = model.predict(X_test, num_iteration=model.best_iteration)
    y_pred = [0 if i < 0.5 else 1 for i in y_pred_prob]
        
    # acc : 正答率
    acc = accuracy_score(y_test,y_pred)
    print('Acc :', acc)
    # f1-score
    f1 = f1_score(y_test,y_pred)
    print('f1-score :', f1)
    # logloss 
    logloss =  log_loss(y_test,y_pred_prob) # 引数 : log_loss(正解クラス,[クラス0の予測確率,クラス1の予測確率])
    print('logloss :', logloss)
    # AUC 
    auc = roc_auc_score(y_test,y_pred_prob) # 引数 : roc_auc_score(正解クラス, クラス1の予測確率)
    print('AUC :', auc) 
        
    acc_list.append(acc)
    f1_list.append(f1)
    auc_list.append(auc)
        
print('Kfold平均 acc:{}, f1-score:{}, auc:{}'.format(np.mean(acc_list), 
                                                         np.mean(f1_list), 
                                                         np.mean(auc_list)))

# importanceを表示する
importance = pd.DataFrame(model.feature_importance(importance_type='gain'), index=list(X.columns), columns=['importance'])
display(importance.sort_values('importance', ascending=False))
good_columns=importance.sort_values('importance', ascending=False).index[0:30]
importance.plot.bar()
# Out:
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000835 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [1]	valid_0's binary_error: 0.223881
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.208955
# [3]	valid_0's binary_error: 0.19403
# [4]	valid_0's binary_error: 0.208955
# [5]	valid_0's binary_error: 0.19403
# [6]	valid_0's binary_error: 0.208955
# [7]	valid_0's binary_error: 0.208955
# [8]	valid_0's binary_error: 0.19403
# [9]	valid_0's binary_error: 0.19403
# [10]	valid_0's binary_error: 0.208955
# [11]	valid_0's binary_error: 0.208955
# [12]	valid_0's binary_error: 0.208955
# [13]	valid_0's binary_error: 0.208955
# [14]	valid_0's binary_error: 0.208955
# [15]	valid_0's binary_error: 0.208955
# [16]	valid_0's binary_error: 0.208955
# [17]	valid_0's binary_error: 0.208955
# [18]	valid_0's binary_error: 0.208955
# [19]	valid_0's binary_error: 0.208955
# [20]	valid_0's binary_error: 0.19403
# [21]	valid_0's binary_error: 0.19403
# [22]	valid_0's binary_error: 0.19403
# [23]	valid_0's binary_error: 0.19403
# Early stopping, best iteration is:
# [3]	valid_0's binary_error: 0.19403
# Acc : 0.7623318385650224
# f1-score : 0.7744680851063831
# logloss : 0.6732195255502568
# AUC : 0.842784749034749
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001177 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [1]	valid_0's binary_error: 0.208955
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.223881
# [3]	valid_0's binary_error: 0.238806
# [4]	valid_0's binary_error: 0.208955
# [5]	valid_0's binary_error: 0.208955
# [6]	valid_0's binary_error: 0.208955
# [7]	valid_0's binary_error: 0.208955
# [8]	valid_0's binary_error: 0.208955
# [9]	valid_0's binary_error: 0.208955
# [10]	valid_0's binary_error: 0.208955
# [11]	valid_0's binary_error: 0.208955
# [12]	valid_0's binary_error: 0.208955
# [13]	valid_0's binary_error: 0.208955
# [14]	valid_0's binary_error: 0.208955
# [15]	valid_0's binary_error: 0.208955
# [16]	valid_0's binary_error: 0.208955
# [17]	valid_0's binary_error: 0.208955
# [18]	valid_0's binary_error: 0.19403
# [19]	valid_0's binary_error: 0.19403
# [20]	valid_0's binary_error: 0.19403
# [21]	valid_0's binary_error: 0.19403
# [22]	valid_0's binary_error: 0.19403
# [23]	valid_0's binary_error: 0.19403
# [24]	valid_0's binary_error: 0.19403
# [25]	valid_0's binary_error: 0.179104
# [26]	valid_0's binary_error: 0.179104
# [27]	valid_0's binary_error: 0.179104
# [28]	valid_0's binary_error: 0.179104
# [29]	valid_0's binary_error: 0.179104
# [30]	valid_0's binary_error: 0.179104
# [31]	valid_0's binary_error: 0.19403
# [32]	valid_0's binary_error: 0.179104
# [33]	valid_0's binary_error: 0.179104
# [34]	valid_0's binary_error: 0.19403
# [35]	valid_0's binary_error: 0.179104
# [36]	valid_0's binary_error: 0.179104
# [37]	valid_0's binary_error: 0.179104
# [38]	valid_0's binary_error: 0.164179
# [39]	valid_0's binary_error: 0.164179
# [40]	valid_0's binary_error: 0.164179
# [41]	valid_0's binary_error: 0.164179
# [42]	valid_0's binary_error: 0.164179
# [43]	valid_0's binary_error: 0.164179
# [44]	valid_0's binary_error: 0.164179
# [45]	valid_0's binary_error: 0.164179
# [46]	valid_0's binary_error: 0.164179
# [47]	valid_0's binary_error: 0.164179
# [48]	valid_0's binary_error: 0.164179
# [49]	valid_0's binary_error: 0.164179
# [50]	valid_0's binary_error: 0.164179
# [51]	valid_0's binary_error: 0.164179
# [52]	valid_0's binary_error: 0.164179
# [53]	valid_0's binary_error: 0.164179
# [54]	valid_0's binary_error: 0.164179
# [55]	valid_0's binary_error: 0.164179
# [56]	valid_0's binary_error: 0.164179
# [57]	valid_0's binary_error: 0.164179
# [58]	valid_0's binary_error: 0.164179
# Early stopping, best iteration is:
# [38]	valid_0's binary_error: 0.164179
# Acc : 0.8340807174887892
# f1-score : 0.8310502283105022
# logloss : 0.508048205056857
# AUC : 0.9164655727155727
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000462 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's binary_error: 0.253731
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.268657
# [3]	valid_0's binary_error: 0.268657
# [4]	valid_0's binary_error: 0.268657
# [5]	valid_0's binary_error: 0.268657
# [6]	valid_0's binary_error: 0.268657
# [7]	valid_0's binary_error: 0.268657
# [8]	valid_0's binary_error: 0.253731
# [9]	valid_0's binary_error: 0.253731
# [10]	valid_0's binary_error: 0.238806
# [11]	valid_0's binary_error: 0.238806
# [12]	valid_0's binary_error: 0.238806
# [13]	valid_0's binary_error: 0.238806
# [14]	valid_0's binary_error: 0.238806
# [15]	valid_0's binary_error: 0.253731
# [16]	valid_0's binary_error: 0.253731
# [17]	valid_0's binary_error: 0.238806
# [18]	valid_0's binary_error: 0.238806
# [19]	valid_0's binary_error: 0.253731
# [20]	valid_0's binary_error: 0.238806
# [21]	valid_0's binary_error: 0.223881
# [22]	valid_0's binary_error: 0.238806
# [23]	valid_0's binary_error: 0.238806
# [24]	valid_0's binary_error: 0.223881
# [25]	valid_0's binary_error: 0.223881
# [26]	valid_0's binary_error: 0.238806
# [27]	valid_0's binary_error: 0.208955
# [28]	valid_0's binary_error: 0.223881
# [29]	valid_0's binary_error: 0.223881
# [30]	valid_0's binary_error: 0.208955
# [31]	valid_0's binary_error: 0.208955
# [32]	valid_0's binary_error: 0.208955
# [33]	valid_0's binary_error: 0.208955
# [34]	valid_0's binary_error: 0.208955
# [35]	valid_0's binary_error: 0.223881
# [36]	valid_0's binary_error: 0.208955
# [37]	valid_0's binary_error: 0.208955
# [38]	valid_0's binary_error: 0.208955
# [39]	valid_0's binary_error: 0.208955
# [40]	valid_0's binary_error: 0.208955
# [41]	valid_0's binary_error: 0.223881
# [42]	valid_0's binary_error: 0.19403
# [43]	valid_0's binary_error: 0.19403
# [44]	valid_0's binary_error: 0.19403
# [45]	valid_0's binary_error: 0.19403
# [46]	valid_0's binary_error: 0.19403
# [47]	valid_0's binary_error: 0.19403
# [48]	valid_0's binary_error: 0.179104
# [49]	valid_0's binary_error: 0.179104
# [50]	valid_0's binary_error: 0.179104
# [51]	valid_0's binary_error: 0.179104
# [52]	valid_0's binary_error: 0.179104
# [53]	valid_0's binary_error: 0.179104
# [54]	valid_0's binary_error: 0.179104
# [55]	valid_0's binary_error: 0.19403
# [56]	valid_0's binary_error: 0.19403
# [57]	valid_0's binary_error: 0.179104
# [58]	valid_0's binary_error: 0.19403
# [59]	valid_0's binary_error: 0.19403
# [60]	valid_0's binary_error: 0.19403
# [61]	valid_0's binary_error: 0.19403
# [62]	valid_0's binary_error: 0.19403
# [63]	valid_0's binary_error: 0.19403
# [64]	valid_0's binary_error: 0.19403
# [65]	valid_0's binary_error: 0.19403
# [66]	valid_0's binary_error: 0.19403
# [67]	valid_0's binary_error: 0.19403
# [68]	valid_0's binary_error: 0.19403
# Early stopping, best iteration is:
# [48]	valid_0's binary_error: 0.179104
# Acc : 0.852017937219731
# f1-score : 0.8421052631578948
# logloss : 0.4812316781038502
# AUC : 0.9140524453024453
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000822 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [1]	valid_0's binary_error: 0.298507
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.298507
# [3]	valid_0's binary_error: 0.298507
# [4]	valid_0's binary_error: 0.298507
# [5]	valid_0's binary_error: 0.298507
# [6]	valid_0's binary_error: 0.283582
# [7]	valid_0's binary_error: 0.283582
# [8]	valid_0's binary_error: 0.283582
# [9]	valid_0's binary_error: 0.283582
# [10]	valid_0's binary_error: 0.268657
# [11]	valid_0's binary_error: 0.268657
# [12]	valid_0's binary_error: 0.253731
# [13]	valid_0's binary_error: 0.253731
# [14]	valid_0's binary_error: 0.253731
# [15]	valid_0's binary_error: 0.238806
# [16]	valid_0's binary_error: 0.238806
# [17]	valid_0's binary_error: 0.238806
# [18]	valid_0's binary_error: 0.253731
# [19]	valid_0's binary_error: 0.253731
# [20]	valid_0's binary_error: 0.253731
# [21]	valid_0's binary_error: 0.268657
# [22]	valid_0's binary_error: 0.268657
# [23]	valid_0's binary_error: 0.283582
# [24]	valid_0's binary_error: 0.283582
# [25]	valid_0's binary_error: 0.283582
# [26]	valid_0's binary_error: 0.283582
# [27]	valid_0's binary_error: 0.283582
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [28]	valid_0's binary_error: 0.298507
# [29]	valid_0's binary_error: 0.283582
# [30]	valid_0's binary_error: 0.298507
# [31]	valid_0's binary_error: 0.298507
# [32]	valid_0's binary_error: 0.298507
# [33]	valid_0's binary_error: 0.313433
# [34]	valid_0's binary_error: 0.298507
# [35]	valid_0's binary_error: 0.298507
# Early stopping, best iteration is:
# [15]	valid_0's binary_error: 0.238806
# Acc : 0.7757847533632287
# f1-score : 0.7619047619047619
# logloss : 0.6126925027146178
# AUC : 0.8605212355212355
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000556 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [1]	valid_0's binary_error: 0.313433
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_error: 0.253731
# [3]	valid_0's binary_error: 0.268657
# [4]	valid_0's binary_error: 0.268657
# [5]	valid_0's binary_error: 0.268657
# [6]	valid_0's binary_error: 0.238806
# [7]	valid_0's binary_error: 0.253731
# [8]	valid_0's binary_error: 0.238806
# [9]	valid_0's binary_error: 0.238806
# [10]	valid_0's binary_error: 0.268657
# [11]	valid_0's binary_error: 0.238806
# [12]	valid_0's binary_error: 0.223881
# /Users/yusuke-n/Library/Python/3.8/lib/python/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [13]	valid_0's binary_error: 0.223881
# [14]	valid_0's binary_error: 0.223881
# [15]	valid_0's binary_error: 0.223881
# [16]	valid_0's binary_error: 0.223881
# [17]	valid_0's binary_error: 0.208955
# [18]	valid_0's binary_error: 0.208955
# [19]	valid_0's binary_error: 0.223881
# [20]	valid_0's binary_error: 0.223881
# [21]	valid_0's binary_error: 0.223881
# [22]	valid_0's binary_error: 0.268657
# [23]	valid_0's binary_error: 0.238806
# [24]	valid_0's binary_error: 0.238806
# [25]	valid_0's binary_error: 0.238806
# [26]	valid_0's binary_error: 0.238806
# [27]	valid_0's binary_error: 0.238806
# [28]	valid_0's binary_error: 0.238806
# [29]	valid_0's binary_error: 0.223881
# [30]	valid_0's binary_error: 0.223881
# [31]	valid_0's binary_error: 0.238806
# [32]	valid_0's binary_error: 0.223881
# [33]	valid_0's binary_error: 0.238806
# [34]	valid_0's binary_error: 0.238806
# [35]	valid_0's binary_error: 0.238806
# [36]	valid_0's binary_error: 0.238806
# [37]	valid_0's binary_error: 0.238806
# Early stopping, best iteration is:
# [17]	valid_0's binary_error: 0.208955
# Acc : 0.7623318385650224
# f1-score : 0.7725321888412018
# logloss : 0.6081347500992099
# AUC : 0.8543677606177607
# Kfold平均 acc:0.7973094170403587, f1-score:0.7964121054641488, auc:0.8776383526383527
#                            importance
# 趣味・休憩                      810.270246
# 快適                         652.338824
# 比較的慣れており，定型化できている業務        403.094383
# 家（書斎など執務向けの場所）             356.608396
# 一人                         288.494651
# 単独作業                       260.318328
# age                        209.851480
# 休憩（業務時間内）                  207.207670
# sex                        175.359921
# web会議                      161.813530
# sleep_3                    152.050268
# weekday                    147.536420
# 作業者/参加者                    147.023921
# 対面会議                       132.495660
# calory_mean                120.282460
# calory_median              119.660550
# heart_mean                 114.269000
# max_windspeed               87.645051
# heart_median                72.934260
# heart_var                   70.850150
# ave_windspeed               58.702500
# 非常に快適                       56.527891
# sunlight_time               53.500350
# 業務外作業                       51.504721
# minutesFairlyActive_mean    51.026669
# minutesLightlyActive_mean   49.213290
# ノンコア業務（自身が本来担当ではない業務）       47.784590
# どちらでもない                     46.289011
# mini_temperature            29.259531
# 企画業務                        24.040840
# <AxesSubplot:>

# %%
# all_importance_kind.to_csv('kind_dams_importance.csv')
# all_importance_detail.to_csv('detail_dams_importance.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import japanize_matplotlib

# %%
plt.clf()
plt.figure(figsize=(12, 9))
sns.heatmap(all_importance_kind, annot=True, fmt='g', cmap='Purples')
plt.show()

# %%
from matplotlib import pyplot

x = 5.0
y = 0.6
s = "上位40%"

pyplot.text(x, y, s)

morning_dams = pd.read_csv('./analyse_data/questionaire_data/morning_dams.csv')
plt.hist(morning_dams['positive_score'],bins=60)
# 縦線
# plt.vlines([morning_dams.describe()["positive_score"]["mean"]], 0, 180, "blue", linestyles='dashed')
plt.vlines(morning_dams["positive_score"].quantile(0.4), 0, 180, "red", linestyles='dashed')
plt.vlines(morning_dams["positive_score"].quantile(0.6), 0, 180, "red", linestyles='dashed')
# morning_dams['positive_score']

# %%
all_data[all_data[['管理者兼作業者', '企画業務',
       'ノンコア業務（自身が本来担当ではない業務）', '管理者', '比較的慣れており，定型化できている業務',
       'コア業務（自身が本来担当している業務）', '共同作業者', '開発業務', '管理業務', '作業者/参加者', '管理の業務',
       '比較的新規性が高く，試行錯誤を伴う定型化できていない業務', '営業業務', '事務業務（サポート業務、経理業務など）',
       '現場業務（主に肉体労働を伴うもの）', '現場（主に肉体労働を伴うもの）', '家（その他）', 'どちらでもない', '一人',
       '家（書斎など執務向けの場所）', '他者あり（同僚など）', '家（リビングなど）', '快適', '職場外のワークスペース',
       '他者あり（無干渉）', '他者あり（同僚）', '職場', '他者あり（家族など）', '店/外', '不快', '非常に快適',
       '職場外ワークスペース', '非常に不快']]!=0].count()
# Out:
# Unnamed: 0           0
# user_id              0
# date                 0
# 対面会議                 0
# 食事                   0
#                     ..
# max_windspeed        0
# ave_vaporpressure    0
# ave_cloudcover       0
# sex                  0
# age                  0
# Length: 122, dtype: int64

# %%
all_data['食事'].query('(all_data.isnotnull()) & (all_data != 0)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-822f215a751c> in <module>
# ----> 1 all_data['食事'].query('(all_data.isnotnull()) & (all_data != 0)')
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'query'
