# %%
import pandas as pd
import sqlalchemy as sa

# %%
url = 'mysql+pymysql://root@localhost:3306/canact?charset=utf8'
url_jis = 'mysql+pymysql://root@localhost:3306/canact?charset=utf8'
engine = sa.create_engine(url, echo=False)
engine_jis = sa.create_engine(url_jis, echo=False)

# %%
query_records = "select * from canact.records where created_at between '2021-01-12 00:00:00' and '2021-02-01 00:00:00' "
records_df = pd.read_sql(query_records,con=engine)

query_activities = "select * from canact.activities where created_at between '2021-01-12 00:00:00' and '2021-02-01 00:00:00' "
activities_df = pd.read_sql(query_activities,con=engine)

query_activity_targets = "select * from canact.activity_targets where created_at between '2021-01-12 00:00:00' and '2021-02-01 00:00:00' "
activity_targets_df = pd.read_sql(query_activity_targets,con=engine)

query_activity_types = "select * from canact.activity_types"
activity_types_df = pd.read_sql(query_activity_types,con=engine)

query_record_types = "select * from canact.record_types"
record_types_df = pd.read_sql(query_record_types,con=engine)

# %%
records_df = pd.read_csv('./datas/records.csv')

# %%
# activities_df.to_csv('./datas/activities.csv')
# activity_targets_df.to_csv('./datas/activity_targets.csv')
# activity_types_df.to_csv('./datas/activity_types.csv')
# record_types_df.to_csv('./datas/activity_types.csv')

# %%
records_df
# Out:
#         Unnamed: 0      id                                              value  \
# 0                0   19068  ["\u8efd\u98df\/\u7d66\u6c34","\u30c8\u30a4\u3...
# 1                1   19069                             ["\u30c8\u30a4\u30ec"]
# 2                2   19070  ["\u5916\u51fa\u3092\u3057\u305f\uff08\u8cb7\u...
# 3                3   19071  ["\u4e0d\u52d5\u7523\u306e\u5185\u898b\u3092\u...
# 4                4   19072  ["\u6563\u6b69\u3084\u904b\u8ee2\u3001\u4f53\u...
# ...            ...     ...                                                ...
# 167145      167145  186213                                                 一人
# 167146      167146  186214                                            どちらでもない
# 167147      167147  186215  ["\u6563\u6b69\u3084\u904b\u8ee2\u3001\u4f53\u...
# 167148      167148  186216  ["\u53cb\u4eba\u3068\u30b4\u30eb\u30d5\u306b\u...
# 167149      167149  186217                                             [null]
#
#         record_type_id  activity_target_id           created_at  \
# 0                   13                3582  2021-01-12 02:15:03
# 1                   13                3585  2021-01-12 03:20:02
# 2                  192                3586  2021-01-12 04:00:03
# 3                  193                3586  2021-01-12 04:00:04
# 4                  192                3589  2021-01-12 05:54:02
# ...                ...                 ...                  ...
# 167145             158               21700  2021-01-31 08:09:04
# 167146             159               21700  2021-01-31 08:09:04
# 167147             192               21702  2021-01-31 08:12:03
# 167148             193               21702  2021-01-31 08:12:03
# 167149             177               21704  2021-01-31 08:52:04
#
#                  updated_at  deleted_at
# 0       2021-01-12 02:15:03         NaN
# 1       2021-01-12 03:20:02         NaN
# 2       2021-01-12 04:00:04         NaN
# 3       2021-01-12 04:01:03         NaN
# 4       2021-01-12 05:55:03         NaN
# ...                     ...         ...
# 167145  2021-01-31 08:09:05         NaN
# 167146  2021-01-31 08:09:05         NaN
# 167147  2021-01-31 08:12:04         NaN
# 167148  2021-01-31 08:13:05         NaN
# 167149  2021-01-31 08:52:04         NaN
#
# [167150 rows x 8 columns]

# %%
record_types_df
# Out:
#       id                                               name  form_type  \
# 0      1                                               業務内容          4
# 1      2                                            業務の位置付け          4
# 2      3                                             業務の新規性          4
# 3      4                                           業務における立場          4
# 4      5                                               業務環境          4
# ..   ...                                                ...        ...
# 189  190                                           成果に結びついた          4
# 190  191  本日１日を振り返っていかがでしたか。普段と異なることがありましたら自由にご記入下さい(任意)...          1
# 191  192         本日１日の活動内容について当てはまるものを選択してください。(複数選択可) （必須）          6
# 192  193  本日１日を振り返っていかがでしたか。どのようなことがありましたか。普段と異なることなどありま...          1
# 193  194                 このFonLogアプリへの要望があれば、遠慮なくご記入お願いします。          1
#
#                                                options  activity_type_id  \
# 0    [["企画業務",false],["開発業務",false],["営業業務",false],...                41
# 1    [["コア業務（自身が本来担当している業務）",false],["ノンコア業務（自身が本来担...                41
# 2    [["比較的慣れており，定型化できている業務",false],["比較的新規性が高く，試行錯...                41
# 3    [["管理者",false],["作業者/参加者",false],["共同作業者",fals...                41
# 4    [["家（書斎など執務向けの場所）",false],["家（リビングなど）",false],...                41
# ..                                                 ...               ...
# 189  [["0: まったくあてはまらない ",false],["1: あてはまらない ",fals...                14
# 190                                                 []                15
# 191  [["散歩や運転、体操などの軽い運動を行った",false],["ジョギングや球技など激しい...                16
# 192                                                 []                16
# 193                                                 []                42
#
#              created_at          updated_at deleted_at
# 0   2020-11-21 21:19:47 2020-11-21 21:19:47        NaT
# 1   2020-11-21 21:21:02 2020-12-04 00:02:29        NaT
# 2   2020-11-21 21:22:28 2020-12-04 00:03:42        NaT
# 3   2020-11-21 21:23:22 2020-11-21 21:23:22        NaT
# 4   2020-11-21 21:24:25 2020-12-04 00:04:29        NaT
# ..                  ...                 ...        ...
# 189 2020-12-09 03:08:01 2020-12-09 03:08:01        NaT
# 190 2020-12-09 03:16:46 2020-12-16 20:44:26        NaT
# 191 2020-12-09 03:18:53 2020-12-15 19:22:12        NaT
# 192 2020-12-15 17:51:57 2020-12-16 20:43:30        NaT
# 193 2021-01-08 00:16:09 2021-01-08 00:16:09        NaT
#
# [194 rows x 8 columns]

# %%
activities_df
# Out:
#           id          started_at         finished_at  user_id  \
# 0       3583 2021-01-11 16:56:00 2021-01-11 17:10:00       15
# 1       3584 2021-01-11 17:27:32 2021-01-11 17:27:41       93
# 2       3585 2021-01-11 18:08:12 2021-01-12 05:53:28       96
# 3       3586 2021-01-11 18:14:57 2021-01-11 18:19:26       15
# 4       3587 2021-01-11 18:58:54 2021-01-11 18:58:54       48
# ...      ...                 ...                 ...      ...
# 18141  21724 2021-01-28 13:00:00 2021-01-28 18:30:00       92
# 18142  21725 2021-01-28 18:30:00 2021-01-28 19:30:00       92
# 18143  21726 2021-01-28 19:30:00 2021-01-28 20:30:00       92
